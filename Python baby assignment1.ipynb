# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
Num1=10
print("Num1=",Num1)
Num2=30
print("Num2=",Num2)
print("Add=",Num1+Num2)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
#Body Mass Index

# %%
num=int(input("Enter your BMI inder:"))
if(num>29.9):
    print("very Over weight")
elif(num<=29.9 and num>=25.0):
    print("over wight")
elif(num<24.9 and num>18.5):
    print("Healthy")
else:
    print("Under weight")
# Out:
# Enter your BMI inder: 77
# very Over weight
