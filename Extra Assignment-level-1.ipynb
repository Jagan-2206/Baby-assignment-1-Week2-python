# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
A=input("enter your institution name:")
# Out:
# enter your institution name: Hope AI

# %%
Name=input("Enter your Name")
Age=input("Enter your Age")
School=input("ENter your School")
Degree=input("Enter your Degree")
# Out:
# Enter your Name Jagan
# Enter your Age 44
# ENter your School Hope AI
# Enter your Degree Masters in AI

# %%
a=43
print("a=",a)
b=34
print("b=",b)
print("Sub=",a-b)
# Out:
# a= 43
# b= 34
# Sub= 9

# %%
a=63
print("a=",a)
b=97
print("b=",b)
print("mul=",a*b)
# Out:
# a= 63
# b= 97
# mul= 6111

# %%
a=76
print("a=",a)
b=31
print("b=",b)
print("Float Div=",a/b)
# Out:
# a= 76
# b= 31
# Float Div= 2.4516129032258065

# %%
a=76
print("a=",a)
b=31
print("b=",b)
print("Floor Div=",a//b)
# Out:
# a= 76
# b= 31
# Floor Div= 2

# %%
a=76
print("a=",a)
b=31
print("b=",b)
print("Modulo=",a%b)
# Out:
# a= 76
# b= 31
# Modulo= 14

# %%
a=4
print("a=",a)
b=4
print("b=",b)
print("Power",a**b)
# Out:
# a= 4
# b= 4
# Power 256
